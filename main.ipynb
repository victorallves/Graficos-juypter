# %%
import pandas as pd
import matplotlib as plt

# %%
confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")

# %%
grafico = confirmed.groupby("Country/Region").sum()
grafico.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.93911  67.709953        0        0        0
# Albania                     0  41.15330  20.168300        0        0        0
# Algeria                     0  28.03390   1.659600        0        0        0
# Andorra                     0  42.50630   1.521800        0        0        0
# Angola                      0 -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  2/28/23  3/1/23  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   209322  209340
# Albania               0        0        0        0  ...   334391  334408
# Algeria               0        0        0        0  ...   271441  271448
# Andorra               0        0        0        0  ...    47866   47875
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
grafico.loc["China"][3:10].plot()
plt.title("Casos confirmados China")
# Out:
# Text(0.5, 1.0, 'Casos confirmados China')

# %%
plt.figure(figsize=(10,8))
grafico.loc["Brazil"][100:110].plot(kind='bar')
plt.title("Casos confirmado no Brasil")
plt.show()

# %%
plt.figure(figsize=(12,5))
data = "3/2/20"
grafico[data].sort_values(ascending=False)[1:10].plot(kind='pie')
plt.title("Os paises com mais casos confirmados na data (3/2/2020) tirando a China (primeiro lugar)")
plt.show()
